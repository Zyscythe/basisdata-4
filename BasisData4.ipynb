# %% [markdown]
# <a href="https://colab.research.google.com/github/Zyscythe/basisdata-4/blob/main/BasisData4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Bab 4 dalam LKPD ini membahas implementasi database untuk sistem administrasi pembayaran sekolah menggunakan MySQL melalui CLI Laragon. Materi mencakup perancangan basis data sederhana dengan perintah DDL untuk membuat database dan tabel, serta DML untuk insert data dan query laporan, sesuai kompetensi dasar mata pelajaran Basis Data SQL RPL kelas XI Ganjil dengan alokasi waktu 2 x 45 menit.�Tujuan utama adalah peserta didik mampu membuat database, mendesain tabel siswa/tagihan/pembayaran dengan relasi FOREIGN KEY, mencatat transaksi, dan menghasilkan laporan status pembayaran. Alat yang dibutuhkan meliputi laptop/PC, Laragon (XAMPP MySQL CLI), dan text editor opsional. Petunjuk pengerjaan menekankan membaca soal teliti, jalankan query di terminal MySQL (mysql -u root), simpan hasil sebagai file .sql jika diminta, dan kerjakan individu sambil tunjukkan output ke guru.�Soal 1: Membuat DatabaseSoal ini meminta pembuatan database bernama adminpembayaransekolah menggunakan perintah SQL sederhana seperti CREATE DATABASE adminpembayaransekolah;. Konteksnya adalah sekolah membutuhkan sistem untuk mengelola data siswa, tagihan, transaksi pembayaran, dan statusnya secara terintegrasi.�Soal 2: Tabel Data SiswaBuatlah tabel siswa dengan struktur: idsiswa (PRIMARY KEY, AUTO_INCREMENT), nis (Nomor Induk Siswa, UNIQUE), namasiswa, kelas, dan alamat. Gunakan perintah CREATE TABLE siswa ( ... ) dengan tipe data yang sesuai seperti INT untuk id/nis, VARCHAR untuk nama/kelas/alamat.�Soal 3: Tabel Tagihan PembayaranTabel tagihan mencakup idtagihan (PRIMARY KEY, AUTO_INCREMENT), idsiswa (FOREIGN KEY ke siswa.idsiswa), jenistagihan (misal SPP bulanan atau uang kegiatan), jumlahtagihan, dan tanggaltagihan. Perintah SQL harus menyertakan constraint FOREIGN KEY (idsiswa) REFERENCES siswa(idsiswa) untuk membangun relasi antar tabel.�Soal 4: Tabel Pembayaran dan TransaksiStruktur tabel pembayaran: idpembayaran (PRIMARY KEY, AUTO_INCREMENT), idtagihan (FOREIGN KEY ke tagihan.idtagihan), tanggalbayar, jumlahbayar, metodebayar. Selain CREATE TABLE, buat contoh INSERT INTO pembayaran (...) VALUES (...) untuk mencatat pembayaran SPP Januari dengan idtagihan=10 sebesar Rp200.000.�Soal 5: Laporan Status PembayaranQuery diperlukan untuk JOIN tabel siswa, tagihan, dan pembayaran, menampilkan kolom namasiswa, jenistagihan, jumlahtagihan, totaldibayar (dihitung dengan SUM(jumlahbayar) atau COALESCE jika null), serta status 'LUNAS' jika totaldibayar >= jumlahtagihan, atau 'BELUM LUNAS' sebaliknya menggunakan CASE statement.�Penilaian berdasarkan ketepatan sintaks SQL, keberhasilan query, kesesuaian struktur tabel, kerapihan relasi, dan ketuntasan soal. Refleksi mencakup hal mudah/menantang serta manfaat FOREIGN KEY untuk menjaga integritas data.�
